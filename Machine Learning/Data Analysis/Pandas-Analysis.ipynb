# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/train.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d0d733d4fab7> in <module>
# ----> 1 df = pd.read_csv("../../data/train.csv")
#       2 df
#
# c:\users\aniket\documents\aniket\learning-ml\ml_env\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.iloc[[0,1], 4]
# Out:
# 0      male
# 1    female
# Name: Sex, dtype: object

# %%
df.loc[[0,1],['Sex','Pclass']]
# Out:
#       Sex  Pclass
# 0    male       3
# 1  female       1

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.set_index('Name', inplace = True)
#df.reset_index(inplace = True)

# %%
df.sort_index(inplace = True)
df
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# ...                                            ...       ...     ...     ...
# de Mulder, Mr. Theodore                        287         1       3    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# van Melkebeke, Mr. Philemon                    869         0       3    male
#
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
filt1 = df['Fare'] >= 200
filt2 = df['SibSp'] > 0

df[filt1 & filt2]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 311          312         1       1
# 341          342         1       1
# 438          439         0       1
# 700          701         1       1
# 742          743         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# 341                     Fortune, Miss. Alice Elizabeth  female  24.0      3
# 438                                  Fortune, Mr. Mark    male  64.0      1
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
#
#      Parch    Ticket     Fare            Cabin Embarked
# ...

# %%
def update_name(name):
    return name[0]
df['Name'] = df['Name'].apply(update_name)
df['Name'] = df['Name'].apply(lambda x: x.upper())
df
# Out:
#      PassengerId  Survived  Pclass Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3    B    male  22.0      1      0
# 1              2         1       1    C  female  38.0      1      0
# 2              3         1       3    H  female  26.0      0      0
# 3              4         1       1    F  female  35.0      1      0
# 4              5         0       3    A    male  35.0      0      0
# ..           ...       ...     ...  ...     ...   ...    ...    ...
# 886          887         0       2    M    male  27.0      0      0
# 887          888         1       1    G  female  19.0      0      0
# 888          889         0       3    J  female   NaN      1      2
# 889          890         1       1    B    male  26.0      0      0
# 890          891         0       3    D    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# ...

# %%
df.apply(len)
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          891
# Embarked       891
# dtype: int64

# %%
df = df.applymap(str)
df.applymap(len)
# Out:
#      PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# 0              1         1       1     1    4    4      1      1       9
# 1              1         1       1     1    6    4      1      1       8
# 2              1         1       1     1    6    4      1      1      16
# 3              1         1       1     1    6    4      1      1       6
# 4              1         1       1     1    4    4      1      1       6
# ..           ...       ...     ...   ...  ...  ...    ...    ...     ...
# 886            3         1       1     1    4    4      1      1       6
# 887            3         1       1     1    6    4      1      1       6
# 888            3         1       1     1    6    3      1      1      10
# 889            3         1       1     1    4    4      1      1       6
# 890            3         1       1     1    4    4      1      1       6
#
#      Fare  Cabin  Embarked
# 0       4      3         1
# 1       7      3         1
# ...

# %%
df.sort_values(by="Age", ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by=["Age","Fare"], ascending = [False, True], inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                                Svensson, Mr. Johan    male  74.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare'].nlargest(10)
# Out:
# 679    512.3292
# 258    512.3292
# 737    512.3292
# 438    263.0000
# 341    263.0000
# 88     263.0000
# 27     263.0000
# 742    262.3750
# 311    262.3750
# 299    247.5208
# Name: Fare, dtype: float64

# %%
df['Fare'].nsmallest(50)
# Out:
# 597    0.0000
# 263    0.0000
# 806    0.0000
# 822    0.0000
# 179    0.0000
# 271    0.0000
# 302    0.0000
# 277    0.0000
# 413    0.0000
# 466    0.0000
# 481    0.0000
# 633    0.0000
# 674    0.0000
# 732    0.0000
# 815    0.0000
# 378    4.0125
# 872    5.0000
# 326    6.2375
# 843    6.4375
# 818    6.4500
# 202    6.4958
# 371    6.4958
# 143    6.7500
# 654    6.7500
# 411    6.8583
# 825    6.9500
# 129    6.9750
# 804    6.9750
# 477    7.0458
# 465    7.0500
# 363    7.0500
# 784    7.0500
# 884    7.0500
# 210    7.0500
# 131    7.0500
# 611    7.0500
# 631    7.0542
# 721    7.0542
# 761    7.1250
# 590    7.1250
# 243    7.1250
# 433    7.1250
# 127    7.1417
# 203    7.2250
# 661    7.2250
# 244    7.2250
# 693    7.2250
# 553    7.2250
# 875    7.2250
# 19     7.2250
# Name: Fare, dtype: float64

# %%
df.iloc[378]
# Out:
# PassengerId                                             147
# Survived                                                  1
# Pclass                                                    3
# Name           Andersson, Mr. August Edvard ("Wennerstrom")
# Sex                                                    male
# Age                                                      27
# SibSp                                                     0
# Parch                                                     0
# Ticket                                               350043
# Fare                                                 7.7958
# Cabin                                                   NaN
# Embarked                                                  S
# Name: 146, dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Fare'].median()
# Out:
# 14.4542

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df['Fare'].mode()
# Out:
# 0    8.05
# dtype: float64

# %% [raw]
# df.median()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Survived'].value_counts(normalize = True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
class_grp = df.groupby(['Pclass'])

# %%
class_grp.get_group(1).describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   216.000000  216.000000   216.0  186.000000  216.000000  216.000000
# mean    461.597222    0.629630     1.0   38.233441    0.416667    0.356481
# std     246.737616    0.484026     0.0   14.802856    0.611898    0.693997
# min       2.000000    0.000000     1.0    0.920000    0.000000    0.000000
# 25%     270.750000    0.000000     1.0   27.000000    0.000000    0.000000
# 50%     472.000000    1.000000     1.0   37.000000    0.000000    0.000000
# 75%     670.500000    1.000000     1.0   49.000000    1.000000    0.000000
# max     890.000000    1.000000     1.0   80.000000    3.000000    4.000000
#
#              Fare
# count  216.000000
# mean    84.154687
# std     78.380373
# min      0.000000
# 25%     30.923950
# 50%     60.287500
# 75%     93.500000
# max    512.329200

# %%
class_grp['Survived'].value_counts(normalize = True)
# Out:
# Pclass  Survived
# 1       1           0.629630
#         0           0.370370
# 2       0           0.527174
#         1           0.472826
# 3       0           0.757637
#         1           0.242363
# Name: Survived, dtype: float64

# %%
class_grp['Survived'].agg(['median','mean'])
# Out:
#         median      mean
# Pclass
# 1            1  0.629630
# 2            0  0.472826
# 3            0  0.242363

# %%
class_grp.agg(['mean','median'])
# Out:
#        PassengerId         Survived               Age            SibSp         \
#               mean median      mean median       mean median      mean median
# Pclass
# 1       461.597222  472.0  0.629630      1  38.233441   37.0  0.416667      0
# 2       445.956522  435.5  0.472826      0  29.877630   29.0  0.402174      0
# 3       439.154786  432.0  0.242363      0  25.140620   24.0  0.615071      0
#
#            Parch              Fare
#             mean median       mean   median
# Pclass
# 1       0.356481      0  84.154687  60.2875
# 2       0.380435      0  20.662183  14.2500
# 3       0.393075      0  13.675550   8.0500

# %%
class_grp['Ticket'].apply(lambda x: x.str.contains('PC'))
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Ticket, Length: 891, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#remove missing values
df.dropna(axis='index',how = 'any', subset= ['Age','Embarked']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Name         712 non-null    object
#  4   Sex          712 non-null    object
#  5   Age          712 non-null    float64
#  6   SibSp        712 non-null    int64
#  7   Parch        712 non-null    int64
#  8   Ticket       712 non-null    object
#  9   Fare         712 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     712 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 72.3+ KB

# %%
df.fillna('Missing')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex      Age  \
# 0                              Braund, Mr. Owen Harris    male       22
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38
# 2                               Heikkinen, Miss. Laina  female       26
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35
# 4                             Allen, Mr. William Henry    male       35
# ..                                                 ...     ...      ...
# ...

# %%
df = pd.read_csv("../data/NIFTY_50.csv")
df
# Out:
#             Date     Open     High      Low    Close       Volume  \
# 0     2000-01-03  1482.15  1592.90  1482.15  1592.20   25358322.0
# 1     2000-01-04  1594.40  1641.95  1594.40  1638.70   38787872.0
# 2     2000-01-05  1634.55  1635.50  1555.05  1595.80   62153431.0
# 3     2000-01-06  1595.80  1639.00  1595.80  1617.60   51272875.0
# 4     2000-01-07  1616.60  1628.25  1597.20  1613.30   54315945.0
# ...          ...      ...      ...      ...      ...          ...
# 5056  2020-05-04  9533.50  9533.50  9266.95  9293.50          NaN
# 5057  2020-05-05  9429.40  9450.90  9190.75  9205.60  725196178.0
# 5058  2020-05-06  9226.80  9346.90  9116.50  9270.90  722185448.0
# 5059  2020-05-07  9234.05  9277.85  9175.90  9199.05  708740416.0
# 5060  2020-05-08  9376.95  9382.65  9238.20  9251.50  609053504.0
#
#           Turnover    P/E   P/B  Div Yield
# 0     8.841500e+09  25.91  4.63       0.95
# 1     1.973690e+10  26.67  4.76       0.92
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
df.loc[0,'Date'].day_name()
# Out:
# 'Monday'

# %%
df['Day'] = df['Date'].dt.day_name()

# %%
df
# Out:
#            Date     Open     High      Low    Close       Volume  \
# 0    2000-01-03  1482.15  1592.90  1482.15  1592.20   25358322.0
# 1    2000-01-04  1594.40  1641.95  1594.40  1638.70   38787872.0
# 2    2000-01-05  1634.55  1635.50  1555.05  1595.80   62153431.0
# 3    2000-01-06  1595.80  1639.00  1595.80  1617.60   51272875.0
# 4    2000-01-07  1616.60  1628.25  1597.20  1613.30   54315945.0
# ...         ...      ...      ...      ...      ...          ...
# 5056 2020-05-04  9533.50  9533.50  9266.95  9293.50          NaN
# 5057 2020-05-05  9429.40  9450.90  9190.75  9205.60  725196178.0
# 5058 2020-05-06  9226.80  9346.90  9116.50  9270.90  722185448.0
# 5059 2020-05-07  9234.05  9277.85  9175.90  9199.05  708740416.0
# 5060 2020-05-08  9376.95  9382.65  9238.20  9251.50  609053504.0
#
#           Turnover    P/E   P/B  Div Yield        Day
# 0     8.841500e+09  25.91  4.63       0.95     Monday
# 1     1.973690e+10  26.67  4.76       0.92    Tuesday
# ...

# %%
df['Date'].max()
# Out:
# Timestamp('2020-05-08 00:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('7431 days 00:00:00')

# %%
filt = (df['Date'] >= '2020')
df.loc[filt]
df.set_index('Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\aniket\documents\aniket\learning-ml\ml_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-99c995de42fc> in <module>
# ...

# %%
highs = df['High'].resample('Y').mean()
highs
# Out:
# Date
# 2000-12-31     1440.323600
# 2001-12-31     1134.478024
# 2002-12-31     1064.767331
# 2003-12-31     1244.100984
# 2004-12-31     1774.005512
# 2005-12-31     2286.715339
# 2006-12-31     3388.747200
# 2007-12-31     4616.730723
# 2008-12-31     4417.680285
# 2009-12-31     4161.107202
# 2010-12-31     5498.631548
# 2011-12-31     5384.035020
# 2012-12-31     5374.329880
# 2013-12-31     5954.560600
# 2014-12-31     7397.669672
# 2015-12-31     8337.653831
# 2016-12-31     8136.359109
# 2017-12-31     9625.885282
# 2018-12-31    10801.753252
# 2019-12-31    11494.463061
# 2020-12-31    10777.191954
# Freq: A-DEC, Name: High, dtype: float64

# %%
# %matplotlib inline

# %%
highs.plot()

# %%
df['High'].plot()

# %%
df[['High','Low']].plot.area()

# %%
df
# Out:
#                Open     High      Low    Close       Volume      Turnover  \
# Date
# 2000-01-03  1482.15  1592.90  1482.15  1592.20   25358322.0  8.841500e+09
# 2000-01-04  1594.40  1641.95  1594.40  1638.70   38787872.0  1.973690e+10
# 2000-01-05  1634.55  1635.50  1555.05  1595.80   62153431.0  3.084790e+10
# 2000-01-06  1595.80  1639.00  1595.80  1617.60   51272875.0  2.531180e+10
# 2000-01-07  1616.60  1628.25  1597.20  1613.30   54315945.0  1.914630e+10
# ...             ...      ...      ...      ...          ...           ...
# 2020-05-04  9533.50  9533.50  9266.95  9293.50          NaN           NaN
# 2020-05-05  9429.40  9450.90  9190.75  9205.60  725196178.0  2.970020e+11
# 2020-05-06  9226.80  9346.90  9116.50  9270.90  722185448.0  3.079810e+11
# 2020-05-07  9234.05  9277.85  9175.90  9199.05  708740416.0  5.970553e+11
# 2020-05-08  9376.95  9382.65  9238.20  9251.50  609053504.0  3.074345e+11
#
#               P/E   P/B  Div Yield        Day
# Date
# ...
