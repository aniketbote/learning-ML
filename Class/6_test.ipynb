# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
train_df = pd.read_csv('mytrain2.csv')
test_df = pd.read_csv('mytest2.csv')

# %%
labelencoder = LabelEncoder()
train_df['thal'] = labelencoder.fit_transform(train_df['thal'])
test_df['thal'] = labelencoder.transform(test_df['thal'])

# %%
train_data, val_data = train_test_split(train_df, test_size=0.2, random_state=133, shuffle= True)
train_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 171   42    1   2       120   295    0        0      162      0      0.0
# 57    52    1   4       108   233    1        0      147      0      0.1
# 99    44    1   4       112   290    0        2      153      0      0.0
# 190   51    0   4       130   305    0        0      142      1      1.2
# 45    57    0   2       130   236    0        2      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 182   54    1   3       125   273    0        2      152      0      0.5
# 1     58    1   2       120   284    0        2      160      0      1.8
# 56    37    1   3       130   250    0        0      187      0      3.5
# 136   54    0   3       160   201    0        0      163      0      0.0
# 161   41    1   4       110   172    0        2      158      0      0.0
#
#      slope  ca  thal  target
# 171      1   0     1       0
# 57       1   3     2       0
# 99       1   1     1       1
# 190      2   0     2       1
# 45       2   1     1       0
# ..     ...  ..   ...     ...
# 182      3   1     1       0
# 1        2   0     1       0
# 56       3   0     1       0
# 136      1   1     1       0
# 161      1   0     2       0
#
# [192 rows x 14 columns]

# %%
val_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 38    66    0   3       146   278    0        2      152      0      0.0
# 30    41    0   2       126   306    0        0      163      0      0.0
# 178   60    1   4       125   258    0        2      141      1      2.8
# 79    45    1   4       142   309    0        2      147      1      0.0
# 119   45    1   2       128   308    0        2      170      0      0.0
# 73    58    0   4       100   248    0        2      122      0      1.0
# 72    71    0   3       110   265    1        2      130      0      0.0
# 13    51    1   4       140   298    0        0      122      1      4.2
# 10    45    0   2       130   234    0        2      175      0      0.6
# 221   56    1   2       120   236    0        0      178      0      0.8
# 120   58    1   4       128   216    0        2      131      1      2.2
# 139   67    0   3       152   277    0        0      172      0      0.0
# 28    58    1   4       114   318    0        1      140      0      4.4
# 109   62    0   4       160   164    0        2      145      0      6.2
# 23    46    0   3       142   177    0        2      160      1      1.4
# 219   51    0   3       120   295    0        2      157      0      0.6
# 180   46    1   4       120   249    0        2      144      0      0.8
# 125   45    1   4       115   260    0        2      185      0      0.0
# 105   57    1   0       130   131    0        1      115      1      1.2
# 37    39    1   3       140   321    0        2      182      0      0.0
# 53    60    0   4       150   258    0        2      157      0      2.6
# 184   43    0   3       122   213    0        0      165      0      0.2
# 74    68    1   0       144   193    1        1      141      0      3.4
# 20    41    1   2       120   157    0        0      182      0      0.0
# 29    56    1   4       130   283    1        2      103      1      1.6
# 129   45    0   4       138   236    0        2      152      1      0.2
# 44    57    1   3       150   126    1        0      173      0      0.2
# 18    35    0   4       138   183    0        0      182      0      1.4
# 122   56    1   2       130   221    0        2      163      0      0.0
# 226   58    0   4       170   225    1        2      146      1      2.8
# 174   43    1   4       115   303    0        0      181      0      1.2
# 126   44    1   2       130   219    0        2      188      0      0.0
# 124   42    1   3       130   180    0        0      150      0      0.0
# 91    44    1   3       120   226    0        0      169      0      0.0
# 27    43    0   4       132   341    1        2      136      1      3.0
# 4     44    1   4       120   169    0        0      144      1      2.8
# 173   62    1   2       120   281    0        2      103      0      1.4
# 39    64    1   4       128   263    0        0      105      1      0.2
# 160   48    1   3       124   255    1        0      175      0      0.0
# 101   58    1   3       105   240    0        2      154      1      0.6
# 175   52    0   3       136   196    0        2      169      0      0.1
# 115   52    1   1       118   186    0        2      190      0      0.0
# 3     46    0   4       138   243    0        2      152      1      0.0
# 157   42    1   1       148   244    0        2      178      0      0.8
# 228   63    1   4       130   330    1        2      132      1      1.8
# 118   56    1   3       130   256    1        2      142      1      0.6
# 95    51    0   3       140   308    0        2      142      0      1.5
# 237   67    1   4       160   286    0        2      108      1      1.5
#
#      slope  ca  thal  target
# 38       2   1     1       0
# 30       1   0     1       0
# 178      2   1     2       0
# 79       2   3     2       1
# 119      1   0     1       0
# 73       2   0     1       0
# 72       1   1     1       0
# 13       2   3     2       1
# 10       2   0     1       0
# 221      1   0     1       0
# 120      2   3     2       0
# 139      1   1     1       0
# 28       3   3     0       1
# 109      3   3     2       1
# 23       3   0     1       0
# 219      1   0     1       0
# 180      1   0     2       0
# 125      1   0     1       0
# 105      1   1     1       0
# 37       1   0     1       0
# 53       2   2     2       1
# 184      2   0     1       0
# 74       1   2     1       0
# 20       1   0     1       0
# 29       3   0     2       1
# 129      2   0     1       0
# 44       1   1     2       0
# 18       1   0     1       0
# 122      1   0     2       0
# 226      2   2     0       1
# 174      2   0     1       0
# 126      1   0     1       0
# 124      1   0     1       0
# 91       1   0     1       0
# 27       2   0     2       1
# 4        3   0     0       1
# 173      2   1     2       1
# 39       2   1     2       0
# 160      1   2     1       0
# 101      2   0     2       0
# 175      2   0     1       0
# 115      2   0     0       0
# 3        2   0     1       0
# 157      1   2     1       0
# 228      1   3     2       1
# 118      2   1     0       1
# 95       1   1     1       0
# 237      2   3     1       1

# %%
def create_model():
    input1 = tf.keras.Input(shape=(14,))
    hidden1 = tf.keras.layers.Dense(units = 12, activation='relu')(input1)
    hidden2 = tf.keras.layers.Dense(units = 6, activation='relu')(hidden1)
    output1 = tf.keras.layers.Dense(units = 2, activation='softmax')(hidden2)
    model = tf.keras.models.Model(inputs = input1, outputs = output1)
    model.summary()
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
history = model.fit(,
          validation_data=val_ds,
          epochs=100,
          verbose = 1,
          steps_per_epoch=steps_per_epoch)
